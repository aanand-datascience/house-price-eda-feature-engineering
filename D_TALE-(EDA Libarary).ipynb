# %% [markdown]
# D-TALE

# %%
# !pip install dtale
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\hp\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %% [markdown]
# Yes Aanand 👍 that’s correct — and what you did is totally normal.
# Let me explain how that works behind the scenes.
#
# ✅ What happens when you run:
# import seaborn as sns
# sns.get_dataset_names()
#
# 👉 Seaborn shows a list of sample datasets stored online in its repository.
#
# These are built-in demo datasets for practice and learning.
#
# Examples:
#
# tips
#
# iris
#
# titanic
#
# flights
#
# penguins
#
# ✅ When you load a dataset like this:
# df = sns.load_dataset("tips")
#
# You feel like you didn’t download anything — but actually:
#
# 👉 Seaborn automatically downloads it from the internet
# 👉 Stores it temporarily
# 👉 Loads it into a Pandas DataFrame
#
# So technically:
# ✔ Download hota hai
# ✔ But automatically (background me)
# ✔ Tumhe manual download nahi karna padta
#
# ✅ Why seaborn provides these datasets
#
# They are for:
#
# ✔ Practice EDA
# ✔ Learning visualization
# ✔ Teaching machine learning
# ✔ Quick examples
#
# Matlab ready-made practice data.
#
# ✅ Where do these datasets come from?
#
# They are hosted online here:
# 👉 Seaborn GitHub dataset repository
#
# Python internet se fetch karta hai jab tum load_dataset() run karte ho.
#
# ❗ Important limitation
#
# Internet required.
#
# Agar internet off ho → dataset load nahi hoga.

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df=sns.load_dataset('planets')

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
import dtale

# %%
dtale.show(df,open_browser=True)

# %%
# DISCLAIMER: 'df' refers to the data you passed in when calling 'dtale.show'

import pandas as pd

if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

# main statistics
stats = df['method'].describe().to_frame().T
uniq_vals = df['method'].value_counts().sort_values(ascending=False)
uniq_vals.index.name = 'value'
uniq_vals.name = 'count'
uniq_vals = uniq_vals.reset_index()
uniq_vals.loc[:, 'type'] = 'string'
s = df['method']
s = s[~s.isnull()].str
char_len = s.len()

def calc_len(x):
	try:
		return len(x)
	except:
		return 0

word_len = s.replace(r'[\s]+', ' ').str.split(' ').apply(calc_len)

def txt_count(r):
	return s.count(r).astype(bool).sum()

char_min=char_len.min()
char_max = char_len.max()
char_mean = char_len.mean()
char_std = char_len.std()
with_space = txt_count(r'\s')
with_accent = txt_count(r'[À-ÖÙ-öù-ÿĀ-žḀ-ỿ]')
with_num = txt_count(r'[\d]')
with_upper = txt_count(r'[A-Z]')
with_lower = txt_count(r'[a-z]')
with_punc = txt_count(
		r'(\!|"|\#|\$|%|&|\'|\(|\)|\*|\+|,|\-|\.|/|\:|\;|\<|\=|\>|\?|@|\[|\\|\]|\^|_|\`|\{|\||\}|\~)'
)
space_at_the_first = txt_count(r'^ ')
space_at_the_end = txt_count(r' $')
multi_space_after_each_other = txt_count(r'\s{2,}')
printable = r'''\w \!"#\$%&'\(\)\*\+,\-\./:;<»«؛،ـ\=>\?@\[\\\]\^_\`\{\|\}~'''
with_hidden = txt_count(r'[^{}]+'.format(printable))
word_min = word_len.min()
word_max = word_len.max()
word_mean = word_len.mean()
word_std = word_len.std()

# %%
stats
# Out:
#        count unique              top freq
# method  1035     10  Radial Velocity  553
# 2026-02-26 10:14:13,462 - ERROR    - Exception occurred while processing request: list index out of range
# Traceback (most recent call last):
#   File "C:\Users\hp\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\dtale\views.py", line 121, in _handle_exceptions
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hp\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\dtale\views.py", line 3899, in chart_export_all
#     output = export_chart(data_id, params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\hp\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\dtale\dash_application\charts.py", line 4158, in export_chart
# ...
